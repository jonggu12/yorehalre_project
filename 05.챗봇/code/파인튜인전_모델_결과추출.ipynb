# %% [markdown]
# <a href="https://colab.research.google.com/github/jonggu12/yorehalre_project/blob/main/%ED%8C%8C%EC%9D%B8%ED%8A%9C%EC%9D%B8%EC%A0%84_%EB%AA%A8%EB%8D%B8_%EA%B2%B0%EA%B3%BC%EC%B6%94%EC%B6%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install huggingface_hub transformers sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 61.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 54.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 80.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
# ...

# %%
import os

os.environ['HUGGINGFACEHUB_API_TOKEN'] = ""

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("heegyu/llama-2-ko-7b-chat")
model = AutoModelForCausalLM.from_pretrained("heegyu/llama-2-ko-7b-chat")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/698 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/5.21M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/652 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.91G [00:00<?, ?B/s]
# ...

# %%
# 기초대사량을 측정하기 위해 갖추어야 할 조건으로 옳은 것은?
# 뼈의 발달과 유지에 필수이며 자외선 차단제 사용 시 합성이 저해되고 부갑상샘호르몬에 의해 활성화되는 비타민 은?
# 비타민 K 결핍 시 나타나는 증상은?
# 골다공증의 치료와 예방을 위해 섭취해야 할 영양소의 조합은?
# 체구성 성분 중 50세 이후 성인기에 증가하는 것은?
# 비만의 BMI와 허리둘레는 뭐야?

# %%
question = "기초대사량을 측정하기 위해 갖추어야 할 조건으로 옳은 것은?"
inputs = tokenizer.encode(question, return_tensors="pt")
output = model.generate(inputs, max_length=150, num_return_sequences=1)
answer = tokenizer.decode(output[0], skip_special_tokens=True)
print(answer)
# Out:
# 기초대사량을측정하기위해갖추어야할조건으로옳은것은?
#
# 1. 100m 달리기
# 2. 100m 달리기
# 3. 100m 달리기
# 4. 100m 달리기
#
# 정답은 3번입니다.

# %%
question = "뼈의 발달과 유지에 필수이며 자외선 차단제 사용 시 합성이 저해되고 부갑상샘호르몬에 의해 활성화되는 비타민 은?"
inputs = tokenizer.encode(question, return_tensors="pt")
output = model.generate(inputs, max_length=200, num_return_sequences=1)
answer = tokenizer.decode(output[0], skip_special_tokens=True)
print(answer)
# Out:
# 뼈의발달과유지에필수이며자외선차단제사용시합성이저해되고부갑상샘호르몬에의해활성화되는비타민은?a)비타민Db)비타민Ac)비타민Kd)비타민E답은 a)비타민D입니다.

# %%
question = "비타민 K 결핍 시 나타나는 증상은?"
inputs = tokenizer.encode(question, return_tensors="pt")
output = model.generate(inputs, max_length=200, num_return_sequences=1)
answer = tokenizer.decode(output[0], skip_special_tokens=True)
print(answer)
# Out:
# 비타민 K결핍시나타나는증상은?비타민 K 결핍은 주로 혈액 내 비타민 K의 농도가 감소하여 발생합니다. 비타민 K 결핍의 증상은 다음과 같습니다.
#
# 1. 혈액 내 비타민 K 농도 감소: 비타민 K 결핍은 혈액 내 비타민 K의 농도가 감소하여 발생합니다. 이로 인해 혈액 내 비타민 K의 농도가 낮아져 혈액 응고 기능이 저하됩니다.
#
# 2. 혈액 응고 장애: 비타민 K 결핍은 혈액 응고 기능의 저하로 이어져 혈액 응고 장애를 유발할 수 있습니다. 혈액 응고 기능이 저하되면 혈전이 생성되어 혈액 순환에 문제를 일으킬 수 있습니다.
#
# 3. 골다공증: 비타민 K 결핍은 골다공증의 위험을 증가시킬

# %%
question = "골다공증의 치료와 예방을 위해 섭취해야 할 영양소의 조합은?"
inputs = tokenizer.encode(question, return_tensors="pt")
output = model.generate(inputs, max_length=200, num_return_sequences=1)
answer = tokenizer.decode(output[0], skip_special_tokens=True)
print(answer)
# Out:
# 골다공증의치료와예방을위해섭취해야할영양소의조합은?
#
# 골다공증은 뼈의 밀도가 감소하여 뼈가 약해지는 질환입니다. 골다공증은 뼈의 밀도가 감소하는 다양한 요인으로 인해 발생할 수 있으며, 이러한 요인에는 유전적 요인, 호르몬 불균형, 약물, 비타민 D 부족, 운동 부족 등이 있습니다. 골다공증의 치료와 예방을 위해 섭취해야 할 영양소의 조합은 다음과 같습니다.
#
# 1. 칼슘: 칼슘은 뼈의 밀도를 유지하는 데 중요한 역할을 합니다. 칼슘은 우유, 유제품, 뼈째 먹는 생선, 치즈, 견과류, 녹색 채소 등에 풍부하게 함유되어 있습니다.
#
# 2. 비타민 D: 비타민 D는 칼슘 흡수를 촉진하고 뼈의 건강을 유지하는 데 중요한 역할을 합니다. 비타민 D는 햇빛

# %%
question = "체구성 성분 중 50세 이후 성인기에 증가하는 것은?"
inputs = tokenizer.encode(question, return_tensors="pt")
output = model.generate(inputs, max_length=200, num_return_sequences=1)
answer = tokenizer.decode(output[0], skip_special_tokens=True)
print(answer)
# Out:
# 체구성성분중 50세이후성인기에증가하는것은?
#
# 1. 콜레스테롤
# 2. 혈압
# 3. 혈당
# 4. 콜레스테롤
#
# 정답은 4번 콜레스테롤입니다.

# %%
question = "비만의 BMI와 허리둘레는 뭐야?"
inputs = tokenizer.encode(question, return_tensors="pt")
output = model.generate(inputs, max_length=200, num_return_sequences=1)
answer = tokenizer.decode(output[0], skip_special_tokens=True)
print(answer)
# Out:
# 비만의 BMI와허리둘레는뭐야?
#
# - BMI는 체중을 키의 제곱으로 나눈 값으로, 비만의 정도를 나타냅니다. BMI가 18.5 미만이면 저체중, 18.5~24.9면 정상, 25 이상이면 비만입니다.
# - 허리둘레는 허리에서 복부까지의 둘레를 말합니다. 허리둘레가 90cm 이상이면 비만입니다.
#
# - 비만은 고혈압, 당뇨병, 고지혈증, 심혈관 질환 등의 질병을 유발할 수 있습니다.
# - 비만은 체중 감량, 규칙적인 운동, 균형 잡힌 식단 등을 통해 예방할 수 있습니다.
# - 비만은 신체적인 건강 문제뿐만 아니라 정신적인 문제도 발생할 수 있으므로, 적절한 관리와 예방이 필요합니다.
